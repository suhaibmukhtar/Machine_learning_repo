# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# %%
data=pd.read_csv('50_Startups.csv')
data.head()
# Out:
#    R&D Spend  Administration  Marketing Spend       State     Profit
# 0  165349.20       136897.80        471784.10    New York  192261.83
# 1  162597.70       151377.59        443898.53  California  191792.06
# 2  153441.51       101145.55        407934.54     Florida  191050.39
# 3  144372.41       118671.85        383199.62    New York  182901.99
# 4  142107.34        91391.77        366168.42     Florida  166187.94

# %%
data.drop(['Administration','State'],axis=1,inplace=True)
data.head()
# Out:
#    R&D Spend  Marketing Spend     Profit
# 0  165349.20        471784.10  192261.83
# 1  162597.70        443898.53  191792.06
# 2  153441.51        407934.54  191050.39
# 3  144372.41        383199.62  182901.99
# 4  142107.34        366168.42  166187.94

# %%
import seaborn as sns
sns.pairplot(data)

# %%
data.columns
# Out:
# Index(['R&D Spend', 'Marketing Spend', 'Profit'], dtype='object')

# %%
# Generate random data
# np.random.seed(123)
x1 =data['R&D Spend']
x2= data['Marketing Spend']
y = data['Profit']

# Create a 3D scatter plot
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# Scatter plot
ax.scatter(x1,x2,y, c='b', marker='o')

# Set labels and title
ax.set_xlabel('X1 Label')
ax.set_ylabel('x2 Label')
ax.set_zlabel('y1 Label')
ax.set_title('3D Scatter Plot')

plt.show()

# %% [markdown]
# ## To Concatenate Two array

# %%
# x=np.c_[x1,x2]

# %%
# x

# %%
x.shape
# Out:
# (50, 2)

# %% [markdown]
# ### To get the same value of intercept as passed add 1, to array

# %%
# x=np.c_[np.ones(x.shape[0]),x]# number of one =number of rows

# %%
# x

# %%
x.shape
# Out:
# (50, 2)

# %%
y
# Out:
# 0     192261.83
# 1     191792.06
# 2     191050.39
# 3     182901.99
# 4     166187.94
# 5     156991.12
# 6     156122.51
# 7     155752.60
# 8     152211.77
# 9     149759.96
# 10    146121.95
# 11    144259.40
# 12    141585.52
# 13    134307.35
# 14    132602.65
# 15    129917.04
# 16    126992.93
# 17    125370.37
# 18    124266.90
# 19    122776.86
# 20    118474.03
# 21    111313.02
# 22    110352.25
# 23    108733.99
# 24    108552.04
# 25    107404.34
# 26    105733.54
# 27    105008.31
# 28    103282.38
# 29    101004.64
# 30     99937.59
# 31     97483.56
# 32     97427.84
# 33     96778.92
# 34     96712.80
# 35     96479.51
# 36     90708.19
# 37     89949.14
# 38     81229.06
# 39     81005.76
# 40     78239.91
# 41     77798.83
# 42     71498.49
# 43     69758.98
# 44     65200.33
# 45     64926.08
# 46     49490.75
# 47     42559.73
# 48     35673.41
# 49     14681.40
# Name: Profit, dtype: float64

# %%
y=np.array(y)
y=y.reshape(-1,1)

# %%
y
# Out:
# array([[192261.83],
#        [191792.06],
#        [191050.39],
#        [182901.99],
#        [166187.94],
#        [156991.12],
#        [156122.51],
#        [155752.6 ],
#        [152211.77],
#        [149759.96],
#        [146121.95],
#        [144259.4 ],
#        [141585.52],
#        [134307.35],
#        [132602.65],
#        [129917.04],
#        [126992.93],
#        [125370.37],
#        [124266.9 ],
#        [122776.86],
#        [118474.03],
#        [111313.02],
#        [110352.25],
#        [108733.99],
#        [108552.04],
#        [107404.34],
#        [105733.54],
#        [105008.31],
#        [103282.38],
#        [101004.64],
#        [ 99937.59],
#        [ 97483.56],
#        [ 97427.84],
#        [ 96778.92],
#        [ 96712.8 ],
#        [ 96479.51],
#        [ 90708.19],
#        [ 89949.14],
#        [ 81229.06],
#        [ 81005.76],
#        [ 78239.91],
#        [ 77798.83],
#        [ 71498.49],
#        [ 69758.98],
#        [ 65200.33],
# ...

# %%
#coeff=[b0 b1 b2 ] i.e. b, m0, m1
# coeff=np.zeros(x.shape[1])

# %%
# coeff=coeff.reshape(-1,1)
# coeff.shape

# %%
# coeff

# %% [markdown]
# """
# predicted=[[1,2,3]   [[]b0],
#            [4,5,6]  * [b1],
#            [7,8,9]]   [b2]]
#
# """

# %% [markdown]
# ## Loss functiom

# %%
# def loss_function(coeff,x,y):
#     predicted,cost,error=0,0,0
#     predicted=np.dot(x,coeff) #performs matrix multiplication nxm---mx1--->nx1
#     error=predicted-y  #matrix subtraction
#     cost=(1/2*x.shape[0])*np.dot(error.T,error)
#     return cost

# %%
# loss_function(coeff,x,y)

# %%
# def gradient_descent(coeff,x,y,learning_rate):

# %%
x=data.iloc[:,:-1]
print(x.shape)
y=data.iloc[:,-1]
print(y.shape)
# Out:
# (50, 2)
# (50,)

# %%
x
# Out:
#     R&D Spend  Marketing Spend
# 0   165349.20        471784.10
# 1   162597.70        443898.53
# 2   153441.51        407934.54
# 3   144372.41        383199.62
# 4   142107.34        366168.42
# 5   131876.90        362861.36
# 6   134615.46        127716.82
# 7   130298.13        323876.68
# 8   120542.52        311613.29
# 9   123334.88        304981.62
# 10  101913.08        229160.95
# 11  100671.96        249744.55
# 12   93863.75        249839.44
# 13   91992.39        252664.93
# 14  119943.24        256512.92
# 15  114523.61        261776.23
# 16   78013.11        264346.06
# 17   94657.16        282574.31
# 18   91749.16        294919.57
# 19   86419.70             0.00
# 20   76253.86        298664.47
# 21   78389.47        299737.29
# 22   73994.56        303319.26
# 23   67532.53        304768.73
# 24   77044.01        140574.81
# 25   64664.71        137962.62
# 26   75328.87        134050.07
# 27   72107.60        353183.81
# 28   66051.52        118148.20
# ...

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.15,random_state=42)

# %%
print(x_train.shape)
print(y_train.shape)
# Out:
# (42, 2)
# (42,)

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()

# %%
x_train_sc=sc.fit_transform(x_train)
x_test_sc=sc.transform(x_test)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr=LinearRegression()
lr.fit(x_train_sc,y_train)
# Out:
# LinearRegression()

# %%
lr.coef_
# Out:
# array([36877.52281465,  3795.23189639])

# %%
lr.intercept_
# Out:
# 115387.46476190475

# %%
y_pred=lr.predict(x_test)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:443: UserWarning: X has feature names, but LinearRegression was fitted without feature names
#   warnings.warn(

# %% [markdown]
# ### To calculate the mean squared Error

# %%
from sklearn.metrics import mean_squared_error
mse=mean_squared_error(y_test,y_pred)
mse
# Out:
# 8.787413244839186e+18

# %%
# Define the coefficients
m1 = 36877.52281465
m2 = 3795.23189639
intercept = 115387.46476190475

# %%
x1=x_train_sc[:,0].copy()
x2=x_train_sc[:,1].copy()

# %%
y = m1 * x1 + m2 * x2 + intercept

# %%
# Create 3D plot
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
# Plot points
ax.scatter(x1,x2, z, c='r', marker='o')
ax.plot(x1,x2,z)
# Set labels
ax.set_xlabel('X1')
ax.set_ylabel('x2')
ax.set_zlabel('y')

plt.title('3D Scatter Plot')

plt.show()
